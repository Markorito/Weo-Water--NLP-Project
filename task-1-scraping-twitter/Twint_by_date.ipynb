# %% [markdown]
# # Twint By Date

# %%
# Install twint if needed
pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
# Install nest_asyncio if needed
pip install nest_asyncio

# %%
import twint
import nest_asyncio
import pandas as pd

nest_asyncio.apply()

# %%
# Extract historical tweets by hashtag and date
def twint_extract(hashtag, from_date, to_date):
    c = twint.Config()
    c.Search = '#' + hashtag
    
    c.Since = from_date
    c.Until = to_date
    
    c.Store_csv = True
    c.Output = hashtag + '.csv'
    
    twint.run.Search(c)

# %%
# Call function
twint_extract('flood', '2019-06-01', '2019-07-01')
# Out:
# 1145114725178662912 2019-06-29 19:40:00 -0400 <livewxradar> Forecast map this evening   Radars at :      https://t.co/HNLPnb8GMF        #wx #weather #storm #hail #wind #flooding #traffic #flood #rain #snow #cooler #ra maps #weekend #Saturday  https://t.co/YGHrfOlSo1
# 1145112798160179200 2019-06-29 19:32:20 -0400 <rjmacaig> This lake been made infront of my house because of an sewer drain that has been backed up snice Friday #Ottawa #Flood #sewer  @ottawacity @OttawaCitizen  https://t.co/0o2uAo84m2
# 1145108449958776833 2019-06-29 19:15:04 -0400 <JuergenKob> 4 Reasons Everyone Should Consider Buying Flood Insurance #Insurance #property #flood   https://t.co/YjNQXgbxtv
# 1145100743248154625 2019-06-29 18:44:26 -0400 <TBWSirSpitta> “Round 2” Tomorrow 3pm🎬🍿🚨 #TooBusyWinning #FLOOD #FOE #SOLID #Houston #bayarea #rap #music #WSHH #gtdigitaldistribution @ University of Houston  https://t.co/EXC5eTxWc9
# ...

# %%
# View csv file
df = pd.read_csv("flood.csv",  lineterminator='\n')
df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1145114725178662912  1145114725178662912  2019-06-29 19:40:00 EDT
# 1  1145112798160179200  1145112798160179200  2019-06-29 19:32:20 EDT
# 2  1145108449958776833  1145108449958776833  2019-06-29 19:15:04 EDT
# 3  1145100743248154625  1145100743248154625  2019-06-29 18:44:26 EDT
# 4  1145099239350890497  1145099239350890497  2019-06-29 18:38:28 EDT
#
#          date      time  timezone             user_id      username  \
# 0  2019-06-29  19:40:00      -400           183688400   livewxradar
# 1  2019-06-29  19:32:20      -400  980485563210969090      rjmacaig
# 2  2019-06-29  19:15:04      -400          3246621015    juergenkob
# 3  2019-06-29  18:44:26      -400           272520199  tbwsirspitta
# 4  2019-06-29  18:38:28      -400           272520199  tbwsirspitta
#
#                           name  \
# 0             Rob Delp Weather
# 1                     Rjmacaig
# 2                   Jürgen Kob
# ...
