# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = "#Flood"
c.Store_csv= True
c.Output="Flooding.csv"

# Run
twint.run.Search(c)

# %%
import pandas as pd

# %%
Data = pd.read_csv("Flooding.csv")
Data.head(3)
# Out:
#                     id      conversation_id               created_at  \
# 0  1391446125564121088  1391372027479707648  2021-05-09 19:33:02 EET
# 1  1391441584915312640  1391441584915312640  2021-05-09 19:15:00 EET
# 2  1391435489165463556  1391435489165463556  2021-05-09 18:50:46 EET
#
#          date      time  timezone              user_id     username  \
# 0  2021-05-09  19:33:02       200  1329709235979104256  ynyshir2020
# 1  2021-05-09  19:15:00       200            183688400  livewxradar
# 2  2021-05-09  18:50:46       200            329923777    djsangsta
#
#                           name place  ... geo source user_rt_id user_rt  \
# 0  Stop Ynyshir Wind Farm 2020   NaN  ... NaN    NaN        NaN     NaN
# 1             Rob Delp Weather   NaN  ... NaN    NaN        NaN     NaN
# 2              Sangsta's Music   NaN  ... NaN    NaN        NaN     NaN
#
#   retweet_id                                           reply_to  retweet_date  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21627 entries, 0 to 21626
# Data columns (total 36 columns):
# id                 21627 non-null int64
# conversation_id    21627 non-null int64
# created_at         21627 non-null object
# date               21627 non-null object
# time               21627 non-null object
# timezone           21627 non-null int64
# user_id            21627 non-null int64
# username           21627 non-null object
# name               21627 non-null object
# place              195 non-null object
# tweet              21627 non-null object
# language           21627 non-null object
# mentions           21627 non-null object
# urls               21627 non-null object
# photos             21627 non-null object
# replies_count      21627 non-null int64
# retweets_count     21627 non-null int64
# likes_count        21627 non-null int64
# hashtags           21627 non-null object
# cashtags           21627 non-null object
# ...

# %%
Data_filtered = Data.drop(columns=["conversation_id","created_at","name","user_rt_id","place",
                                   "language","mentions","urls","photos","replies_count","retweets_count",
                                   "likes_count","link","quote_url","video","thumbnail",
                                   "near","geo","source","user_rt","retweet_id","retweet_date","translate",
                                    "trans_src","trans_dest","retweet","cashtags"] ,inplace = True)

# %%
Data
# Out:
#                         id        date      time  timezone  \
# 0      1391446125564121088  2021-05-09  19:33:02       200
# 1      1391441584915312640  2021-05-09  19:15:00       200
# 2      1391435489165463556  2021-05-09  18:50:46       200
# 3      1391425730437816322  2021-05-09  18:12:00       200
# 4      1391422799433113600  2021-05-09  18:00:21       200
# ...                    ...         ...       ...       ...
# 21622  1352073453990506500  2021-01-21  04:00:06       200
# 21623  1352068367289614337  2021-01-21  03:39:53       200
# 21624  1352064850843758593  2021-01-21  03:25:55       200
# 21625  1352058750375350273  2021-01-21  03:01:40       200
# 21626  1352058678019502080  2021-01-21  03:01:23       200
#
#                    user_id         username  \
# 0      1329709235979104256      ynyshir2020
# 1                183688400      livewxradar
# 2                329923777        djsangsta
# 3               3088630438  calderdaleforum
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21627 entries, 0 to 21626
# Data columns (total 11 columns):
# id          21627 non-null int64
# date        21627 non-null object
# time        21627 non-null object
# timezone    21627 non-null int64
# user_id     21627 non-null int64
# username    21627 non-null object
# tweet       21627 non-null object
# hashtags    21627 non-null object
# cashtags    21627 non-null object
# retweet     21627 non-null bool
# reply_to    21627 non-null object
# dtypes: bool(1), int64(3), object(7)
# memory usage: 1.7+ MB
