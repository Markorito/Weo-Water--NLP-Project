# %%
import pandas as pd
import numpy as np
import csv
from tqdm import tqdm
import base64
from github import Github
from io import BytesIO

# %%
# Username of your GitHub account
 
username = 'mansimht'
 
# Personal Access Token (PAO) from your GitHub account
 
token = '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'
 
# Creates a re-usable session object with your creds in-built
 
github_session = requests.Session()
github_session.auth = (username, token)

# %%
def download_data (url):

    url = url # Make sure the url is the raw version of the file on GitHub
    download = github_session.get(url).content

    df= pd.read_csv(BytesIO(download))
    df.to_csv('tweets_df_USGS_line1.csv')

    return df

# %%
url = 'https://raw.githubusercontent.com/OmdenaAI/WeoWater/main/task-1-scraping-twitter/tweets_df_USGS_line1'
tweets_df_USG_line1 = download_data(url)

# %%
tweets_df_USG_line1
# Out:
#           Tweet User Id  ... Language
# 0            1550621509  ...       en
# 1             308297667  ...       en
# 2   1379199206771019779  ...       en
# 3              22962704  ...       en
# 4   1343943153427087361  ...       en
# 5              20187715  ...       en
# 6            3293109928  ...       en
# 7            2875820413  ...       en
# 8   1343943153427087361  ...       en
# 9   1343943153427087361  ...       en
# 10  1343943153427087361  ...       en
# 11  1343943153427087361  ...       en
# 12  1343943153427087361  ...       en
# 13  1343943153427087361  ...       en
# 14             18347570  ...       en
# 15            949118761  ...       en
# 16            385231250  ...       en
# 17           2424440299  ...       en
# 18  1343943153427087361  ...       en
# 19  1343943153427087361  ...       en
# 20  1343943153427087361  ...       en
# 21  1343943153427087361  ...       en
# 22  1343943153427087361  ...       en
# 23  1343943153427087361  ...       en
# ...
