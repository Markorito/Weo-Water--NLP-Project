# %%
import sys
# !{sys.executable} -m pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
import sys
# !{sys.executable} -m pip install nest_asyncio

# %%
# Import packages to use
import twint
import pandas as pd
import matplotlib.pyplot as plt

# Patches asyncio to allow the running of multiple event loops in Jupyter Notebooks.
# Fixes: "RuntimeError: This event loop is already running"
import nest_asyncio

nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = "#drought"
c.Store_csv= True
c.Output="drought.csv"

# Run
twint.run.Search(c)

# %%
import pandas as pd

# %%
drought = pd.read_csv("drought.csv")
drought.head(6)
# Out:
#                     id      conversation_id               created_at  \
# 0  1396558921456775170  1396558921456775170  2021-05-23 21:09:28 CET
# 1  1396554576363495428  1396554576363495428  2021-05-23 20:52:12 CET
# 2  1396550298571722753  1396550298571722753  2021-05-23 20:35:12 CET
# 3  1396542064259702790  1396542064259702790  2021-05-23 20:02:29 CET
# 4  1396540407262040065  1396540407262040065  2021-05-23 19:55:54 CET
# 5  1396536304553369618  1396536304553369618  2021-05-23 19:39:36 CET
#
#          date      time  timezone              user_id         username  \
# 0  2021-05-23  21:09:28       100   910623276778405888         ai6yrham
# 1  2021-05-23  20:52:12       100  1386756713433477120         vl_cohen
# 2  2021-05-23  20:35:12       100  1255609631776190464  plecowaterwatch
# 3  2021-05-23  20:02:29       100            253615321    alexwitzleben
# 4  2021-05-23  19:55:54       100  1179518575872299009       draperjace
# ...

# %%
drought_filtered = drought.drop(columns=["conversation_id","created_at","name","user_rt_id",
                                   "language","mentions","urls","photos","replies_count","retweets_count",
                                   "likes_count","link","quote_url","video","thumbnail",
                                   "near","geo","source","user_rt","retweet_id","retweet_date","translate",
                                    "trans_src","trans_dest","retweet","cashtags"] ,inplace = True)

# %%
drought.to_csv("droughtData.csv", index = False)

# %%
df = pd.read_csv('droughtData.csv',
                 lineterminator='\n')
df.head(3)
# Out:
#                     id        date      time  timezone              user_id  \
# 0  1396558921456775170  2021-05-23  21:09:28       100   910623276778405888
# 1  1396554576363495428  2021-05-23  20:52:12       100  1386756713433477120
# 2  1396550298571722753  2021-05-23  20:35:12       100  1255609631776190464
#
#           username place                                              tweet  \
# 0         ai6yrham   NaN                                   #oregon #drought
# 1         vl_cohen   NaN  We should 🙏🏻 for more frequent gentle rain for...
# 2  plecowaterwatch   NaN  New blog post is up!    https://t.co/Kmli8YYD0...
#
#                                             hashtags reply_to
# 0                              ['oregon', 'drought']       []
# 1                                        ['drought']       []
# 2  ['smarthome', 'smartdevice', 'savewater', 'dro...       []

# %%
df.info
# Out:
# <bound method DataFrame.info of                          id        date      time  timezone  \
# 0       1396558921456775170  2021-05-23  21:09:28       100
# 1       1396554576363495428  2021-05-23  20:52:12       100
# 2       1396550298571722753  2021-05-23  20:35:12       100
# 3       1396542064259702790  2021-05-23  20:02:29       100
# 4       1396540407262040065  2021-05-23  19:55:54       100
# ...                     ...         ...       ...       ...
# 222382   747244060427968512  2016-06-27  02:44:01       100
# 222383   747244059488509952  2016-06-27  02:44:01       100
# 222384   747222949745197056  2016-06-27  01:20:08       100
# 222385   747221976377344000  2016-06-27  01:16:16       100
# 222386   747219876096286720  2016-06-27  01:07:55       100
#
#                     user_id         username place  \
# 0        910623276778405888         ai6yrham   NaN
# 1       1386756713433477120         vl_cohen   NaN
# 2       1255609631776190464  plecowaterwatch   NaN
# ...
